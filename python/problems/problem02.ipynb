# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
import pprint
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint.pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '1.71',
#          'average_price': '301.7636',
#          'buy_price': '297',
#          'closing_price': '296',
#          'max_price': '318',
#          'min_price': '284',
#          'opening_price': '291',
#          'sell_price': '300',
#          'units_traded': '1532105.14221994',
#          'volume_1day': '1532105.14221994',
#          'volume_7day': '10470911.666567873398941736'},
#  'ADA': {'24H_fluctate': '5.3',
#          '24H_fluctate_rate': '5.76',
#          'average_price': '96.2484',
#          'buy_price': '95.5',
#          'closing_price': '97.2',
#          'max_price': '103',
#          'min_price': '91.3',
#          'opening_price': '91.9',
#          'sell_price': '96.8',
#          'units_traded': '6378698.54472842',
#          'volume_1day': '6378698.54472842',
#          'volume_7day': '63696728.85071544'},
#  'AE': {'24H_fluctate': '8',
#         '24H_fluctate_rate': '1.55',
# ...

# %%
for key in data:
    if key != 'date':
        if float(data[key]['opening_price']) + float(data[key]['max_price']) - float(data[key]['min_price']) > float(data[key]['max_price']):
            print(f'{key} : 상승장')
        else:
            print(f'{key} : 하락장')
#---
# for key in data:
#     if key == 'date':
#         continue
#     if float(data[key]['opening_price']) + float(data[key]['max_price']) - float(data[key]['min_price']) > float(data[key]['max_price']):
#         print(f'{key} : 상승장')
#     else:
#         print(f'{key} : 하락장')
# Out:
# BTC : 상승장
# ETH : 상승장
# DASH : 상승장
# LTC : 상승장
# ETC : 상승장
# XRP : 상승장
# BCH : 상승장
# XMR : 상승장
# ZEC : 상승장
# QTUM : 상승장
# BTG : 상승장
# EOS : 상승장
# ICX : 상승장
# VET : 상승장
# TRX : 상승장
# ELF : 상승장
# MITH : 상승장
# MCO : 상승장
# OMG : 상승장
# KNC : 상승장
# GNT : 상승장
# ZIL : 상승장
# ETHOS : 상승장
# PAY : 상승장
# WAX : 하락장
# POWR : 상승장
# LRC : 상승장
# GTO : 상승장
# STEEM : 상승장
# STRAT : 상승장
# ZRX : 하락장
# REP : 상승장
# AE : 상승장
# XEM : 상승장
# SNT : 상승장
# ADA : 상승장
# PPT : 상승장
# CTXC : 상승장
# CMT : 상승장
# THETA : 상승장
# WTC : 상승장
# ITC : 상승장
# TRUE : 상승장
# ABT : 상승장
# RNT : 상승장
# PLY : 상승장
# WAVES : 상승장
# LINK : 상승장
# ENJ : 상승장
# PST : 상승장
# SALT : 상승장
# RDN : 상승장
# LOOM : 상승장
# PIVX : 상승장
# INS : 상승장
# BCD : 상승장
# BZNT : 상승장
# XLM : 상승장
# OCN : 상승장
# BSV : 상승장
# TMTG : 상승장
# BAT : 상승장
# WET : 상승장
# XVG : 상승장
# IOST : 상승장
# POLY : 상승장
# HC : 상승장
# ROM : 상승장
# AMO : 상승장
# ETZ : 상승장
# ARN : 상승장
# APIS : 하락장
# MTL : 상승장
# DACC : 상승장
# DAC : 상승장
# BHP : 상승장
# BTT : 상승장
# HDAC : 상승장
# NPXS : 상승장
# AUTO : 상승장
# GXC : 상승장
# ...

# %%
for coin, coin_data in data.items():
    if  type(coin_data) == type(dict()):
        continue
#--이하 동문
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-333144b69535> in <module>
#       2     if  type(coin_data) == type(dict()):
#       3         continue
# ----> 4     if float(data[coin]['opening_price']) - float(data[coin]['min_price']) > 0:
#       5             print(f'{coin} : 상승장')
#       6     else:
#
# TypeError: string indices must be integers

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}

# %%
average = sum(student.values())/len(student)
print(average)
# Out:
# 83.25

# %%
total_score = 0
count  = 0
for score in student.values():
    total_score += score
    count += 1
print(total_score/count)
# Out:
# 83.25

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']

# %%
blood_total={}
for blood_type in set(blood):
    blood_total[blood_type] = blood.count(blood_type)
print(blood_total)

#------ 
print({x:blood.count(x) for x in blood})

#------ 이렇게 짤 수 있도록 !
blood_total2={}
# (반복)하나씩 꺼내서 확인한다
for blood_type in blood:
    # 나온적이 없으면, 키와 value 1로 만든다.
    if blood_type not in blood_total2.keys():
        blood_total2[blood_type] = 1
    # 나온적이 있으면 value 값을 1 증가시킨다.
    else:
        blood_total2[blood_type] += 1
print(blood_total2)
# Out:
# {'B': 2, 'A': 5, 'AB': 3, 'O': 4}
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}

# %%
UBD = 172212
for movie in movies:
    if movies[movie] <= 80 * UBD:
        print(movie)
        
#------
print([movie for movie in movies if movies[movie] <= 80*UBD])

#------
for movie, count in movies.items():
    if count / 172212 < 80:
        print(movie)
# Out:
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타
# ['7번방의선물', '괴물', '도둑들', '베테랑', '아바타']
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타

# %%
num = 1200000000000000000000
print(f'{num:,}')
print('{:,}'.format(num))
# Out:
# 1,200,000,000,000,000,000,000
# 1,200,000,000,000,000,000,000

# %%
list_x = ['1','2','3','4']
[int(x) for x in list_x]
# Out:
# [1, 2, 3, 4]

# %%
blood_type = {'A', 'B', 'A', 'O', 'AB', 'AB', 'O', 'A', 'B', 'O', 'B','AB'}

blood_total = {}
for blood in blood_type:
    print(blood)
    if blood not in blood_total.keys():
        blood_total[blood] = 1
    else:
        blood_total[blood] += 1

print(blood_total)
# Out:
# B
# A
# AB
# O
# {'B': 1, 'A': 1, 'AB': 1, 'O': 1}
